# %% [markdown]
# <a href="https://colab.research.google.com/github/Anvinhtr/jupyter1/blob/main/FunAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Python Code For A Number Guessing Game

# %% [markdown]
# This is a game that will allow you to guess a number between 1 and 10 and when you get it correct, the number of attempts will also show

# %%
import random
attempts_list = []
def show_score():
    if len(attempts_list) <= 0:
        print("There is currently no high score, it's yours to take!")
    else:
        print("The current high score is {} attempts".format(min(attempts_list)))
        
        
def start_game():
    random_number = int(random.randint(1, 10))
    print("Hello! Welcome to the game of guesses!")
    player_name = input("What is your name? ")
    wanna_play = input("Hi, {}, would you like to play the guessing game? (Enter Yes/No) ".format(player_name))
    attempts = 0
    show_score()
    while wanna_play.lower() == "yes":
        try:
            guess = input("Pick a number between 1 and 10 ")
            if int(guess) < 1 or int(guess) > 10:
                raise ValueError("Please guess a number within the given range")
            if int(guess) == random_number:
                print("You got it!")
                attempts += 1
                attempts_list.append(attempts)
                print("It took you {} attempts".format(attempts))
                play_again = input("Would you like to play again? (Enter Yes/No) ")
                attempts = 0
                show_score()
                random_number = int(random.randint(1, 10))
                if play_again.lower() == "no":
                    print("Have a good day!")
                    break
            elif int(guess) > random_number:
                print("It's lower")
                attempts += 1
            elif int(guess) < random_number:
                print("It's higher")
                attempts += 1
        except ValueError as err:
            print("That is not a valid value. Try again...")
            print("({})".format(err))
    else:
        print("Have a good one!")
if __name__ == '__main__':
    start_game()
# Out:
# Hello! Welcome to the game of guesses!

# %% [markdown]
# The game will end until you guess the correct number

# %% [markdown]
# show_score will show the score after you guess the number correctly

# %% [markdown]
# As you guess incorrectly, the number of attempts will increase

# %% [markdown]
# The int values are between 1 and 10 so any number below or higher will result in ValueError
